# %% [markdown]
# # Statistics

# %% [markdown]
# Statistics refers to the mathematics and techniques with which we understand data.

# %%
names =["Ama", "Bima", "Cima", "Duma","Ema"]
num_friends = [80, 49, 11, 19, 25]

from matplotlib import pyplot as plt 

plt.bar(names, num_friends) 
plt.title("histogram") 
plt.show()

# %% [markdown]
# #Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(170, 10, 250)# Mean, SD and number of values

plt.hist(x)
plt.show()

# %%
from numpy import random
x=random.randint(100, size=(50))
print(x)
# Out:
# [34 34 24 50  4 47 99 43 67 13 77  5 68 63 20  0 29  4 55 69 47 51 25 53
#  41 20 51 66 66 29 81 38  5 53  2 62 53 21 48 37 75 96 34  8 87 62 13 79
#  81 27]

# %%
print(len(x))
print(max(x))
print(min(x))
y=sorted(x)
print(y)
# Out:
# 50
# 99
# 0
# [0, 2, 4, 4, 5, 5, 8, 13, 13, 20, 20, 21, 24, 25, 27, 29, 29, 34, 34, 34, 37, 38, 41, 43, 47, 47, 48, 50, 51, 51, 53, 53, 53, 55, 62, 62, 63, 66, 66, 67, 68, 69, 75, 77, 79, 81, 81, 87, 96, 99]

# %%
def mean(x):
 return sum(x) / len(x)
m=mean(num_friends) # 7.333333
print(m)
# Out:
# 36.8

# %%
def median(v):
  """finds the 'middle-most' value of v"""
  n= len(v)
  sorted_v = sorted(v)
  midpoint = n // 2
 
  if n % 2 == 1:
  # if odd, return the middle value
    return sorted_v[midpoint]
  else:
   # if even, return the average of the middle values
    lo = midpoint - 1
    hi = midpoint

  return (sorted_v[lo] + sorted_v[hi]) / 2

md=median(x)
print(md)
# Out:
# 47.0

# %% [markdown]
# [python 3.4 sratistics module](https://www.w3schools.com/python/module_statistics.asp)

# %%
import statistics

mxd=statistics.mode(num_friends) 
print (mxd)
# Out:
# 80

# %%
v=statistics.variance(num_friends)
print(v)
# Out:
# 784.2

# %% [markdown]
# # Correlation

# %% [markdown]
# Correlation describes how two variables such as number of friends and time spent on site relate to each other.
# [link] (https://www.datacamp.com/tutorial/tutorial-datails-on-correlation)
#
# ![py-corr-1.webp](data:image/webp;base64,...)

# %%
# generate related variables
from numpy import mean
from numpy import std
from numpy.random import randn
from numpy.random import seed
from matplotlib import pyplot
# seed random number generator
seed(1)
# prepare data
data1 = 20 * randn(1000) + 100
data2 = data1 + (10 * randn(1000) + 50)
# summarize
print('data1: mean=%.3f stdv=%.3f' % (mean(data1), std(data1)))
print('data2: mean=%.3f stdv=%.3f' % (mean(data2), std(data2)))
# plot
pyplot.scatter(data1, data2)
pyplot.show()
# Out:
# data1: mean=100.776 stdv=19.620
# data2: mean=151.050 stdv=22.358
