# %%
import pandas as pd

# %%
url_data='https://raw.githubusercontent.com/jichaojoyce/data-science-project-1/master/survey-results-public.csv'
df=pd.read_csv(url_data)
url_schema='https://raw.githubusercontent.com/jichaojoyce/data-science-project-1/master/survey-results-schema.csv'
schema_df = pd.read_csv(url_schema, index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
schema_df
# Out:
#                                                                Question
# Column
# Respondent                                         Respondent ID number
# Professional                 Which of the following best describes you?
# ProgramHobby          Do you program as a hobby or contribute to ope...
# Country                         In which country do you currently live?
# University            Are you currently enrolled in a formal, degree...
# ...                                                                 ...
# QuestionsInteresting                     The questions were interesting
# QuestionsConfusing                         The questions were confusing
# InterestedAnswers     I'm interested in learning how other developer...
# Salary                What is your current annual base salary, befor...
# ExpectedSalary        You said before that you are currently learnin...
#
# [154 rows x 1 columns]

# %%
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
df['StackOverflowSatisfaction'].head(15)
# Out:
# Respondent
# 1      9.0
# 2      8.0
# 3      8.0
# 4     10.0
# 5      NaN
# 6      6.0
# 7      8.0
# 8      7.0
# 9      8.0
# 10     9.0
# 11    10.0
# 12     NaN
# 13     5.0
# 14    10.0
# 15     8.0
# Name: StackOverflowSatisfaction, dtype: float64

# %%
df['StackOverflowSatisfaction'].median()
# Out:
# 9.0

# %%
df.median()
# Out:
# <ipython-input-13-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# CareerSatisfaction               8.000000
# JobSatisfaction                  7.000000
# HoursPerWeek                     1.000000
# StackOverflowSatisfaction        9.000000
# Salary                       50000.000000
# ExpectedSalary               29364.263691
# dtype: float64

# %%
df.describe()
# Out:
#        CareerSatisfaction  JobSatisfaction  HoursPerWeek  \
# count        42695.000000     40376.000000  20600.000000
# mean             7.300574         6.957078      3.952282
# std              1.955444         2.167652      7.564722
# min              0.000000         0.000000      0.000000
# 25%              6.000000         6.000000      1.000000
# 50%              8.000000         7.000000      1.000000
# 75%              9.000000         8.000000      4.000000
# max             10.000000        10.000000     40.000000
#
#        StackOverflowSatisfaction         Salary  ExpectedSalary
# count               36592.000000   12891.000000     2566.000000
# mean                    8.429875   56298.480641    33142.220468
# std                     1.390635   39880.905277    30162.988829
# min                     0.000000       0.000000        0.000000
# 25%                     8.000000   26440.371839     4490.492484
# 50%                     9.000000   50000.000000    29364.263691
# ...

# %%
df['StackOverflowSatisfaction'].count()
# Out:
# 36592

# %%
df['ProgramHobby']
# Out:
# Respondent
# 1                        Yes, both
# 2                        Yes, both
# 3                        Yes, both
# 4                        Yes, both
# 5        Yes, I program as a hobby
#                    ...
# 51388    Yes, I program as a hobby
# 51389                           No
# 51390    Yes, I program as a hobby
# 51391    Yes, I program as a hobby
# 51392                           No
# Name: ProgramHobby, Length: 51392, dtype: object

# %%
df['ProgramHobby'].value_counts()
# Out:
# Yes, I program as a hobby                    24801
# Yes, both                                    13756
# No                                            9787
# Yes, I contribute to open source projects     3048
# Name: ProgramHobby, dtype: int64

# %%
df['QuestionsInteresting']
# Out:
# Respondent
# 1        Strongly agree
# 2        Somewhat agree
# 3                 Agree
# 4                 Agree
# 5                   NaN
#               ...
# 51388             Agree
# 51389             Agree
# 51390               NaN
# 51391             Agree
# 51392    Strongly agree
# Name: QuestionsInteresting, Length: 51392, dtype: object

# %%
schema_df.loc['QuestionsInteresting']
# Out:
# Question    The questions were interesting
# Name: QuestionsInteresting, dtype: object

# %%
df['QuestionsInteresting'].value_counts()
# Out:
# Agree                16061
# Somewhat agree       13448
# Strongly agree        2897
# Disagree              1876
# Strongly disagree      254
# Name: QuestionsInteresting, dtype: int64

# %%
df['QuestionsInteresting'].value_counts(normalize=True)
# Out:
# Agree                0.465051
# Somewhat agree       0.389391
# Strongly agree       0.083883
# Disagree             0.054320
# Strongly disagree    0.007355
# Name: QuestionsInteresting, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# United States      11455
# India               5197
# United Kingdom      4395
# Germany             4143
# Canada              2233
#                    ...
# Pitcairn Island        1
# French Guyana          1
# Gabon                  1
# Monaco                 1
# Saint Helena           1
# Name: Country, Length: 201, dtype: int64

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('India')
# Out:
#                       Professional               ProgramHobby Country  \
# Respondent
# 27          Professional developer                         No   India
# 62          Professional developer  Yes, I program as a hobby   India
# 67          Professional developer                         No   India
# 95          Professional developer                  Yes, both   India
# 108         Professional developer  Yes, I program as a hobby   India
# ...                            ...                        ...     ...
# 51341       Professional developer  Yes, I program as a hobby   India
# 51344       Professional developer  Yes, I program as a hobby   India
# 51347       Professional developer                  Yes, both   India
# 51348                      Student                         No   India
# 51362       Professional developer  Yes, I program as a hobby   India
#
#                 University                        EmploymentStatus  \
# Respondent
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt]['QuestionsInteresting'].value_counts()
# Out:
# Agree                1227
# Somewhat agree        790
# Strongly agree        351
# Disagree              119
# Strongly disagree      23
# Name: QuestionsInteresting, dtype: int64

# %%
country_grp['QuestionsInteresting'].value_counts(normalize=True).loc['China']
# Out:
# QuestionsInteresting
# Somewhat agree       0.433071
# Agree                0.385827
# Disagree             0.102362
# Strongly agree       0.055118
# Strongly disagree    0.023622
# Name: QuestionsInteresting, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 63016.0

# %%
country_grp['JobSatisfaction'].agg(['median', 'mean']).loc['Canada']
# Out:
# median    8.000000
# mean      7.291379
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['HighestEducationParents'].str.contains('degree').sum()
# Out:
# 2065

# %%
country_respondents = df['Country'].value_counts()
country_respondents
# Out:
# United States      11455
# India               5197
# United Kingdom      4395
# Germany             4143
# Canada              2233
#                    ...
# Pitcairn Island        1
# French Guyana          1
# Gabon                  1
# Monaco                 1
# Saint Helena           1
# Name: Country, Length: 201, dtype: int64
